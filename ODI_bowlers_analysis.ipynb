# %% [markdown]
# ## Data Preprocessing on ODI Bowlers Dataset.
# Done by: Audity Ghosh
# <br>3rd Year, CSE, RUET
#
# #### Objectives:
# - Reading a specific sheet from an excel file.
# - Getting the insights of data
# - Extracting new information from a column.
# - Removing redundant information from the dataset.

# %% [markdown]
# ## Importing necessary modules

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Read the data sheet into dataframe

# %%
df = pd.read_excel("ODI_cricket.xlsx", sheet_name="bowler", engine="openpyxl")

display(df.head())
# Out:
#                          Player       Span  Mat  Inns  Balls   Runs  Wkts  \
# 0  M Muralitharan (Asia/ICC/SL)  1993-2011  350   341  18811  12326   534
# 1             Wasim Akram (PAK)  1984-2003  356   351  18186  11812   502
# 2            Waqar Younis (PAK)  1989-2003  262   258  12698   9919   416
# 3          WPUJC Vaas (Asia/SL)  1994-2008  322   320  15775  11014   400
# 4  Shahid Afridi (Asia/ICC/PAK)  1996-2015  398   372  17670  13632   395
#
#      Ave  Econ    SR   4   5
# 0  23.08  3.93  35.2  15  10
# 1  23.52  3.89  36.2  17   6
# 2  23.84  4.68  30.5  14  13
# 3  27.53  4.18  39.4   9   4
# 4  34.51  4.62  44.7   4   9

# %% [markdown]
# Here our excel file contained two sheets, so we specified which sheet to take for dataframe.

# %% [markdown]
# ## First 10 rows of the dataframe

# %%
display(df.head(10))
# Out:
#                          Player       Span  Mat  Inns  Balls   Runs  Wkts  \
# 0  M Muralitharan (Asia/ICC/SL)  1993-2011  350   341  18811  12326   534
# 1             Wasim Akram (PAK)  1984-2003  356   351  18186  11812   502
# 2            Waqar Younis (PAK)  1989-2003  262   258  12698   9919   416
# 3          WPUJC Vaas (Asia/SL)  1994-2008  322   320  15775  11014   400
# 4  Shahid Afridi (Asia/ICC/PAK)  1996-2015  398   372  17670  13632   395
# 5       SM Pollock (Afr/ICC/SA)  1996-2008  303   297  15712   9631   393
# 6          GD McGrath (AUS/ICC)  1993-2007  250   248  12970   8391   381
# 7                   B Lee (AUS)  2000-2012  221   217  11185   8877   380
# 8               SL Malinga (SL)  2004-2019  226   220  10936   9760   338
# 9         A Kumble (Asia/INDIA)  1990-2007  271   265  14496  10412   337
#
#      Ave  Econ    SR   4   5
# 0  23.08  3.93  35.2  15  10
# 1  23.52  3.89  36.2  17   6
# 2  23.84  4.68  30.5  14  13
# 3  27.53  4.18  39.4   9   4
# 4  34.51  4.62  44.7   4   9
# 5  24.50  3.67  39.9  12   5
# 6  22.02  3.88  34.0   9   7
# 7  23.36  4.76  29.4  14   9
# 8  28.87  5.35  32.3  11   8
# 9  30.89  4.30  43.0   8   2

# %% [markdown]
# ## The meaning of each column

# %% [markdown]
#     Player: Name of the bowlers of the dataset.
#     Span: The active years of the bowler
#     Mat: The number of matches the bowler has played.
#     Inns: The number of innings the bowler has played.
#     Balls: The number of balls the bowler has bowled.
#     Wkts: The number of wickets the specific bowler has taken.
#     Runs: The number of runs yielded.
#     Ave: The normal number of runs yielded per wicket. (Ave = Runs/Wkts)
#     Econ: The normal number of runs surrendered per over. (Econ = Runs/(Balls/6)).
#     SR: The normal number of balls bowled per wicket taken. (SR = Balls/Wkts)
#     4: The quantity of innings where the bowler took precisely four wickets.
#     5: The quantity of innings where the bowler took precisely five wickets.

# %% [markdown]
# ## No of rows and columns in the dataset

# %%
print("No of rows ", df.shape[0])
print("No of columns ", df.shape[1])
# Out:
# No of rows  77
# No of columns  12

# %% [markdown]
# ##  Data statistics and Data types

# %%
df.describe()
# Out:
#               Mat        Inns         Balls          Runs        Wkts  \
# count   77.000000   77.000000     77.000000     77.000000   77.000000
# mean   194.402597  181.194805   8839.402597   6671.714286  233.805195
# std     82.485606   67.958393   3316.055457   2245.839029   84.406603
# min     80.000000   76.000000   4074.000000   2821.000000  151.000000
# 25%    136.000000  128.000000   6182.000000   5058.000000  173.000000
# 50%    170.000000  164.000000   8054.000000   6192.000000  199.000000
# 75%    227.000000  218.000000  10750.000000   8021.000000  272.000000
# max    463.000000  372.000000  18811.000000  13632.000000  534.000000
#
#              Ave       Econ         SR          4          5
# count  77.000000  77.000000  77.000000  77.000000  77.000000
# mean   28.958052   4.596753  37.909091   6.350649   2.870130
# std     4.826768   0.515814   6.060901   3.556929   2.530606
# min    18.680000   3.300000  26.100000   1.000000   0.000000
# 25%    24.970000   4.280000  33.000000   3.000000   1.000000
# 50%    29.290000   4.660000  37.800000   6.000000   2.000000
# 75%    31.900000   4.920000  41.400000   8.000000   4.000000
# max    44.480000   5.830000  52.500000  17.000000  13.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  77 non-null     object
#  1   Span    77 non-null     object
#  2   Mat     77 non-null     int64
#  3   Inns    77 non-null     int64
#  4   Balls   77 non-null     int64
#  5   Runs    77 non-null     int64
#  6   Wkts    77 non-null     int64
#  7   Ave     77 non-null     float64
#  8   Econ    77 non-null     float64
#  9   SR      77 non-null     float64
#  10  4       77 non-null     int64
#  11  5       77 non-null     int64
# dtypes: float64(3), int64(7), object(2)
# memory usage: 7.3+ KB

# %% [markdown]
# #### Here we can see, there is no null elements, all counts are equal to total number of rows.

# %% [markdown]
# ## Renaming the column names appropriately

# %%
# renaming the column names
df = df.rename(columns={ 
                        'Mat':'Matches_Played',
                        'Inns': 'Innings_Played',
                        'Balls': 'Balls_Bowled',
                        'Runs': 'Runs_Yielded',
                        'Wkts': 'Wickets_Taken',
                        'Ave': 'Bowling_Average',
                        'Econ': 'Economy_Rate',
                        'SR': 'Strike_Rate',
                        4: "Four_Wickets_in_an_innings",
                        5: "Five_Wickets_in_an_innings"
})

# splitting the 'Player' column to get the information about 'Country'
df[["Player_Name", "Country"]] = df['Player'].str.split("(", expand=True)

# dropping the 'Player' columns
df = df.drop('Player', axis=1)

# remove the ")" from the 'Country' column
df['Country'] = df['Country'].str.replace(")", "")

# splitting the 'Span' column based on the "-"
df[['Start_year', 'End_year']] = df['Span'].str.split("-", expand=True)

# removing the "Span" column
df = df.drop("Span", axis=1)

# rearrange the columns
new_col_sequence = ['Player_Name', 'Country', 'Start_year', 'End_year', 'Matches_Played', 'Innings_Played', 'Balls_Bowled', 
                    'Runs_Yielded', 'Wickets_Taken','Bowling_Average', 'Economy_Rate', 'Strike_Rate', 
                    'Four_Wickets_in_an_innings', 'Five_Wickets_in_an_innings']
df = df[new_col_sequence]

display(df.head(10))
# Out:
#        Player_Name       Country Start_year End_year  Matches_Played  \
# 0  M Muralitharan    Asia/ICC/SL       1993     2011             350
# 1     Wasim Akram            PAK       1984     2003             356
# 2    Waqar Younis            PAK       1989     2003             262
# 3      WPUJC Vaas        Asia/SL       1994     2008             322
# 4   Shahid Afridi   Asia/ICC/PAK       1996     2015             398
# 5      SM Pollock     Afr/ICC/SA       1996     2008             303
# 6      GD McGrath        AUS/ICC       1993     2007             250
# 7           B Lee            AUS       2000     2012             221
# 8      SL Malinga             SL       2004     2019             226
# 9        A Kumble     Asia/INDIA       1990     2007             271
#
#    Innings_Played  Balls_Bowled  Runs_Yielded  Wickets_Taken  Bowling_Average  \
# 0             341         18811         12326            534            23.08
# 1             351         18186         11812            502            23.52
# 2             258         12698          9919            416            23.84
# 3             320         15775         11014            400            27.53
# 4             372         17670         13632            395            34.51
# 5             297         15712          9631            393            24.50
# 6             248         12970          8391            381            22.02
# 7             217         11185          8877            380            23.36
# 8             220         10936          9760            338            28.87
# 9             265         14496         10412            337            30.89
#
#    Economy_Rate  Strike_Rate  Four_Wickets_in_an_innings  \
# 0          3.93         35.2                          15
# 1          3.89         36.2                          17
# 2          4.68         30.5                          14
# 3          4.18         39.4                           9
# 4          4.62         44.7                           4
# 5          3.67         39.9                          12
# 6          3.88         34.0                           9
# 7          4.76         29.4                          14
# 8          5.35         32.3                          11
# 9          4.30         43.0                           8
#
#    Five_Wickets_in_an_innings
# 0                          10
# 1                           6
# 2                          13
# 3                           4
# 4                           9
# 5                           5
# 6                           7
# 7                           9
# 8                           8
# 9                           2

# %% [markdown]
# ### Find the player who played for the longest time

# %% [markdown]
# ##### Here the "Span" column was a string type, so when it was divided into Start_year and End_year, they both were string types as well. So it was necessary to convert them to integer type to get the difference.

# %%
df['Start_year'] = df['Start_year'].astype('int') 
df['End_year'] = df['End_year'].astype('int')

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Player_Name                 77 non-null     object
#  1   Country                     77 non-null     object
#  2   Start_year                  77 non-null     int32
#  3   End_year                    77 non-null     int32
#  4   Matches_Played              77 non-null     int64
#  5   Innings_Played              77 non-null     int64
#  6   Balls_Bowled                77 non-null     int64
#  7   Runs_Yielded                77 non-null     int64
#  8   Wickets_Taken               77 non-null     int64
#  9   Bowling_Average             77 non-null     float64
#  10  Economy_Rate                77 non-null     float64
#  11  Strike_Rate                 77 non-null     float64
#  12  Four_Wickets_in_an_innings  77 non-null     int64
#  13  Five_Wickets_in_an_innings  77 non-null     int64
# dtypes: float64(3), int32(2), int64(7), object(2)
# memory usage: 7.9+ KB
# None

# %% [markdown]
# ##### As we have End_year and Start_year give the information about Years_Played, they became redundant columns, so we discarded them.

# %%
df['Years_played'] = df['End_year'] - df['Start_year']

df = df.drop(['Start_year', "End_year"], axis=1)

# rearrange the columns
new_col_sequence = ['Player_Name', 'Country', 'Years_played', 'Matches_Played', 'Innings_Played', 'Balls_Bowled', 
                    'Runs_Yielded', 'Wickets_Taken','Bowling_Average', 'Economy_Rate', 'Strike_Rate', 
                    'Four_Wickets_in_an_innings', 'Five_Wickets_in_an_innings']
df = df[new_col_sequence]

display(df.head(10))
# Out:
#        Player_Name       Country  Years_played  Matches_Played  \
# 0  M Muralitharan    Asia/ICC/SL            18             350
# 1     Wasim Akram            PAK            19             356
# 2    Waqar Younis            PAK            14             262
# 3      WPUJC Vaas        Asia/SL            14             322
# 4   Shahid Afridi   Asia/ICC/PAK            19             398
# 5      SM Pollock     Afr/ICC/SA            12             303
# 6      GD McGrath        AUS/ICC            14             250
# 7           B Lee            AUS            12             221
# 8      SL Malinga             SL            15             226
# 9        A Kumble     Asia/INDIA            17             271
#
#    Innings_Played  Balls_Bowled  Runs_Yielded  Wickets_Taken  Bowling_Average  \
# 0             341         18811         12326            534            23.08
# 1             351         18186         11812            502            23.52
# 2             258         12698          9919            416            23.84
# 3             320         15775         11014            400            27.53
# 4             372         17670         13632            395            34.51
# 5             297         15712          9631            393            24.50
# 6             248         12970          8391            381            22.02
# 7             217         11185          8877            380            23.36
# 8             220         10936          9760            338            28.87
# 9             265         14496         10412            337            30.89
#
#    Economy_Rate  Strike_Rate  Four_Wickets_in_an_innings  \
# 0          3.93         35.2                          15
# 1          3.89         36.2                          17
# 2          4.68         30.5                          14
# 3          4.18         39.4                           9
# 4          4.62         44.7                           4
# 5          3.67         39.9                          12
# 6          3.88         34.0                           9
# 7          4.76         29.4                          14
# 8          5.35         32.3                          11
# 9          4.30         43.0                           8
#
#    Five_Wickets_in_an_innings
# 0                          10
# 1                           6
# 2                          13
# 3                           4
# 4                           9
# 5                           5
# 6                           7
# 7                           9
# 8                           8
# 9                           2

# %% [markdown]
# ##### zip was used for combined traversal of two columns and df[column].max() was used to get the maximum value of the column

# %%
print("The player who played for the longest period: ")
for player,active in zip(df["Player_Name"],df["Years_played"]):
    if active==df["Years_played"].max():
        print(player,active)
# Out:
# The player who played for the longest period:
# SR Tendulkar  23

# %% [markdown]
# #### Alternative Solution

# %%
df[df['Years_played']==df['Years_played'].max()]['Player_Name']
# Out:
# 72    SR Tendulkar
# Name: Player_Name, dtype: object

# %% [markdown]
# Here 72 is the serial number in the dataset.

# %% [markdown]
# ## The player who played for the shortest period

# %%
print("The player who played for the shortest period: ")
for player,active in zip(df["Player_Name"],df["Years_played"]):
    if active==df["Years_played"].min():
        print(player,active)
# Out:
# The player who played for the shortest period:
# BKV Prasad  7
# Saeed Ajmal  7
# BAW Mendis  7
# Rashid Khan  7

# %% [markdown]
# #### Alternative Solution

# %%
df[df['Years_played']==df['Years_played'].min()]['Player_Name']
# Out:
# 40     BKV Prasad
# 49    Saeed Ajmal
# 73     BAW Mendis
# 74    Rashid Khan
# Name: Player_Name, dtype: object

# %% [markdown]
# Left column denotes serial number

# %% [markdown]
# ### Count how many players played for ICC

# %%
def icc_check(x):
    if "ICC" in x:
        return "Yes"
    else:
        return "No"

# %%
df['played_for_ICC'] = df['Country'].apply(icc_check)

# %%
print(df['played_for_ICC'].value_counts())
# Out:
# No     64
# Yes    13
# Name: played_for_ICC, dtype: int64

# %% [markdown]
# ##### Here, we can see there are 13 playes who played for ICC

# %% [markdown]
# ### Count how many Austrailian bowlers are there

# %%
# function for checking austrailian bowlers
def austrailia_check(x):
    if "AUS" in x:
        return "Yes"
    else:
        return "No"

# %%
df['played_for_Austrailia'] = df['Country'].apply(austrailia_check) #function applied to specific column values.

display(df.head(10))
# Out:
#        Player_Name       Country  Years_played  Matches_Played  \
# 0  M Muralitharan    Asia/ICC/SL            18             350
# 1     Wasim Akram            PAK            19             356
# 2    Waqar Younis            PAK            14             262
# 3      WPUJC Vaas        Asia/SL            14             322
# 4   Shahid Afridi   Asia/ICC/PAK            19             398
# 5      SM Pollock     Afr/ICC/SA            12             303
# 6      GD McGrath        AUS/ICC            14             250
# 7           B Lee            AUS            12             221
# 8      SL Malinga             SL            15             226
# 9        A Kumble     Asia/INDIA            17             271
#
#    Innings_Played  Balls_Bowled  Runs_Yielded  Wickets_Taken  Bowling_Average  \
# 0             341         18811         12326            534            23.08
# 1             351         18186         11812            502            23.52
# 2             258         12698          9919            416            23.84
# 3             320         15775         11014            400            27.53
# 4             372         17670         13632            395            34.51
# 5             297         15712          9631            393            24.50
# 6             248         12970          8391            381            22.02
# 7             217         11185          8877            380            23.36
# 8             220         10936          9760            338            28.87
# 9             265         14496         10412            337            30.89
#
#    Economy_Rate  Strike_Rate  Four_Wickets_in_an_innings  \
# 0          3.93         35.2                          15
# 1          3.89         36.2                          17
# 2          4.68         30.5                          14
# 3          4.18         39.4                           9
# 4          4.62         44.7                           4
# 5          3.67         39.9                          12
# 6          3.88         34.0                           9
# 7          4.76         29.4                          14
# 8          5.35         32.3                          11
# 9          4.30         43.0                           8
#
#    Five_Wickets_in_an_innings played_for_ICC played_for_Austrailia
# 0                          10            Yes                    No
# 1                           6             No                    No
# 2                          13             No                    No
# 3                           4             No                    No
# 4                           9            Yes                    No
# 5                           5            Yes                    No
# 6                           7            Yes                   Yes
# 7                           9             No                   Yes
# 8                           8             No                    No
# 9                           2             No                    No

# %%
print(df['played_for_Austrailia'].value_counts())
# Out:
# No     67
# Yes    10
# Name: played_for_Austrailia, dtype: int64

# %% [markdown]
# #### Here, we can see there are 10 Austrailian Bowlers in the dataset.

# %% [markdown]
# ### Check if there is any Bangladeshi Bowler

# %%
#function to find bd player
def Bangladesh_check(x):
    if "BAN" in x:
        return "Yes"
    else:
        return "No"

# %%
df['played_for_Bangladesh'] = df['Country'].apply(Bangladesh_check) # function applied to specific column

display(df.sample(10))
# Out:
#          Player_Name     Country  Years_played  Matches_Played  \
# 44       L Klusener           SA             8             171
# 15       AB Agarkar        INDIA             9             191
# 25      N Kapil Dev        INDIA            16             225
# 65        RJ Hadlee           NZ            17             115
# 5        SM Pollock   Afr/ICC/SA            12             303
# 23  Harbhajan Singh   Asia/INDIA            17             236
# 47        RA Jadeja        INDIA            11             168
# 74      Rashid Khan          AFG             7              80
# 70          GB Hogg          AUS            12             123
# 18        JH Kallis   Afr/ICC/SA            18             328
#
#     Innings_Played  Balls_Bowled  Runs_Yielded  Wickets_Taken  \
# 44             164          7336          5751            192
# 15             188          9484          8021            288
# 25             221         11202          6945            253
# 65             112          6182          3407            158
# 5              297         15712          9631            393
# 23             227         12479          8973            269
# 47             164          8557          7024            188
# 74              76          4074          2821            151
# 70             113          5564          4188            156
# 18             283         10750          8680            273
#
#     Bowling_Average  Economy_Rate  Strike_Rate  Four_Wickets_in_an_innings  \
# 44            29.95          4.70         38.2                           1
# 15            27.85          5.07         32.9                          10
# 25            27.45          3.71         44.2                           3
# 65            21.56          3.30         39.1                           1
# 5             24.50          3.67         39.9                          12
# 23            33.35          4.31         46.3                           2
# 47            37.36          4.92         45.5                           7
# 74            18.68          4.15         26.9                           5
# 70            26.84          4.51         35.6                           3
# 18            31.79          4.84         39.3                           2
#
#     Five_Wickets_in_an_innings played_for_ICC played_for_Austrailia  \
# 44                           6             No                    No
# 15                           2             No                    No
# 25                           1             No                    No
# 65                           5             No                    No
# 5                            5            Yes                    No
# 23                           3             No                    No
# 47                           1             No                    No
# 74                           4             No                    No
# 70                           2             No                   Yes
# 18                           2            Yes                    No
#
#    played_for_Bangladesh
# 44                    No
# 15                    No
# 25                    No
# 65                    No
# 5                     No
# 23                    No
# 47                    No
# 74                    No
# 70                    No
# 18                    No

# %%
print(df['played_for_Bangladesh'].value_counts())
# Out:
# No     74
# Yes     3
# Name: played_for_Bangladesh, dtype: int64

# %% [markdown]
# ##### Here, we can observe there are three Bangladeshi Bowlers

# %%
found_bd_player=False

for state in df['played_for_Bangladesh']:
    if state == "Yes":
        print("Yee! We found a Bangladeshi Bowler")
        found_bd_player=True
        break
if(found_bd_player is False):
    print("No, there is no Bangladeshi Bowler")
# Out:
# Yee! We found a Bangladeshi Bowler

# %% [markdown]
# ## Find the player with the lowest Economic Rate

# %%
print("The player who has the lowest economic rate: ")
for player,eco in zip(df["Player_Name"],df["Economy_Rate"]):
    if eco==df["Economy_Rate"].min():
        print(player,eco)
# Out:
# The player who has the lowest economic rate:
# RJ Hadlee  3.3

# %% [markdown]
# #### Alternative

# %%
df[df['Economy_Rate']==df['Economy_Rate'].min()]['Player_Name']
# Out:
# 65    RJ Hadlee
# Name: Player_Name, dtype: object

# %% [markdown]
# ## Find the player with the lowest Strike Rate

# %%
print("The player who has the lowest strike rate: ")
for player,strike in zip(df["Player_Name"],df["Strike_Rate"]):
    if strike==df["Strike_Rate"].min():
        print(player,strike)
# Out:
# The player who has the lowest strike rate:
# MA Starc  26.1

# %% [markdown]
# #### Alternative

# %%
df[df['Strike_Rate']==df['Strike_Rate'].min()]['Player_Name']
# Out:
# 41    MA Starc
# Name: Player_Name, dtype: object

# %% [markdown]
# Left column denotes serial number.

# %% [markdown]
# ### Find the player with the lowest bowling average

# %%
print("The player who has the lowest bowling average: ")
for player,avg in zip(df["Player_Name"],df["Bowling_Average"]):
    if avg==df["Bowling_Average"].min():
        print(player,avg)
# Out:
# The player who has the lowest bowling average:
# Rashid Khan  18.68

# %% [markdown]
# #### Alternative

# %%
df[df['Bowling_Average']==df['Bowling_Average'].min()]['Player_Name']
# Out:
# 74    Rashid Khan
# Name: Player_Name, dtype: object

# %% [markdown]
# Left column denotes serial number.

# %%
df.sample(20)
# Out:
#          Player_Name      Country  Years_played  Matches_Played  \
# 29        HH Streak       Afr/ZIM            12             189
# 53        SCJ Broad           ENG            10             121
# 44       L Klusener            SA             8             171
# 51      Aaqib Javed           PAK            10             163
# 46         M Morkel        Afr/SA            11             117
# 68      M Prabhakar         INDIA            12             130
# 36        CL Cairns        ICC/NZ            15             215
# 62         CH Gayle        ICC/WI            20             301
# 23  Harbhajan Singh    Asia/INDIA            17             236
# 70          GB Hogg           AUS            12             123
# 6        GD McGrath       AUS/ICC            14             250
# 15       AB Agarkar         INDIA             9             191
# 0    M Muralitharan   Asia/ICC/SL            18             350
# 69          A Nehra    Asia/INDIA            10             120
# 33     Abdur Razzak           BAN            10             153
# 66     Shoaib Malik           PAK            20             287
# 43        CL Hooper            WI            16             227
# 60         TA Boult            NZ             9              93
# 16  Shakib Al Hasan           BAN            16             221
# 11        J Srinath         INDIA            12             229
#
#     Innings_Played  Balls_Bowled  Runs_Yielded  Wickets_Taken  \
# 29             185          9468          7129            239
# 53             121          6109          5364            178
# 44             164          7336          5751            192
# 51             159          8012          5721            182
# 46             114          5760          4761            188
# 68             127          6360          4534            157
# 36             186          8168          6594            201
# 62             199          7424          5926            167
# 23             227         12479          8973            269
# 70             113          5564          4188            156
# 6              248         12970          8391            381
# 15             188          9484          8021            288
# 0              341         18811         12326            534
# 69             120          5751          4981            157
# 33             152          7965          6065            207
# 66             217          7958          6192            158
# 43             203          9573          6958            193
# 60              93          5117          4261            169
# 16             218         11351          8401            285
# 11             227         11935          8847            315
#
#     Bowling_Average  Economy_Rate  Strike_Rate  Four_Wickets_in_an_innings  \
# 29            29.82          4.51         39.6                           7
# 53            30.13          5.26         34.3                           9
# 44            29.95          4.70         38.2                           1
# 51            31.43          4.28         44.0                           2
# 46            25.32          4.95         30.6                           7
# 68            28.87          4.27         40.5                           4
# 36            32.80          4.84         40.6                           3
# 62            35.48          4.78         44.4                           3
# 23            33.35          4.31         46.3                           2
# 70            26.84          4.51         35.6                           3
# 6             22.02          3.88         34.0                           9
# 15            27.85          5.07         32.9                          10
# 0             23.08          3.93         35.2                          15
# 69            31.72          5.19         36.6                           5
# 33            29.29          4.56         38.4                           5
# 66            39.18          4.66         50.3                           1
# 43            36.05          4.36         49.6                           3
# 60            25.21          4.99         30.2                           8
# 16            29.47          4.44         39.8                           9
# 11            28.08          4.44         37.8                           7
#
#     Five_Wickets_in_an_innings played_for_ICC played_for_Austrailia  \
# 29                           1             No                    No
# 53                           1             No                    No
# 44                           6             No                    No
# 51                           4             No                    No
# 46                           2             No                    No
# 68                           2             No                    No
# 36                           1            Yes                    No
# 62                           1            Yes                    No
# 23                           3             No                    No
# 70                           2             No                   Yes
# 6                            7            Yes                   Yes
# 15                           2             No                    No
# 0                           10            Yes                    No
# 69                           2             No                    No
# 33                           4             No                    No
# 66                           0             No                    No
# 43                           0             No                    No
# 60                           5             No                    No
# 16                           3             No                    No
# 11                           3             No                    No
#
#    played_for_Bangladesh
# 29                    No
# 53                    No
# 44                    No
# 51                    No
# 46                    No
# 68                    No
# 36                    No
# 62                    No
# 23                    No
# 70                    No
# 6                     No
# 15                    No
# 0                     No
# 69                    No
# 33                   Yes
# 66                    No
# 43                    No
# 60                    No
# 16                   Yes
# 11                    No

# %% [markdown]
# ## Remove redundant information

# %%
def asia_check(x):
    if "Asia" in x:
        return "Yes"
    else:
        return "No"

# %%
def africa_check(x):
    if "Afr" in x:
        return "Yes"
    else:
        return "No"

# %%
df['played_for_Asia'] = df['Country'].apply(asia_check)
df['played_for_Africa'] = df['Country'].apply(africa_check)

# %%
print(df['played_for_Asia'].value_counts())
print(df['played_for_Africa'].value_counts())
# Out:
# No     65
# Yes    12
# Name: played_for_Asia, dtype: int64
# No     72
# Yes     5
# Name: played_for_Africa, dtype: int64

# %%
df['Country'] = df['Country'].str.replace("ICC/", "")
df['Country'] = df['Country'].str.replace("/ICC", "")
df['Country'] = df['Country'].str.replace("Asia/", "")
df['Country'] = df['Country'].str.replace("Afr/", "")

display(df.sample(10))
# Out:
#          Player_Name Country  Years_played  Matches_Played  Innings_Played  \
# 69          A Nehra    INDIA            10             120             120
# 58        IK Pathan    INDIA             8             120             118
# 13         SK Warne      AUS            12             194             191
# 17           Z Khan    INDIA            12             200             197
# 37         DJ Bravo       WI            10             164             150
# 52         Umar Gul      PAK            13             130             128
# 36        CL Cairns       NZ            15             215             186
# 16  Shakib Al Hasan      BAN            16             221             218
# 21      JM Anderson      ENG            13             194             191
# 40       BKV Prasad    INDIA             7             161             160
#
#     Balls_Bowled  Runs_Yielded  Wickets_Taken  Bowling_Average  Economy_Rate  \
# 69          5751          4981            157            31.72          5.19
# 58          5855          5142            173            29.72          5.26
# 13         10642          7541            293            25.73          4.25
# 17         10097          8301            282            29.43          4.93
# 37          6511          5874            199            29.51          5.41
# 52          6064          5253            179            29.34          5.19
# 36          8168          6594            201            32.80          4.84
# 16         11351          8401            285            29.47          4.44
# 21          9584          7861            269            29.22          4.92
# 40          8129          6332            196            32.30          4.67
#
#     Strike_Rate  Four_Wickets_in_an_innings  Five_Wickets_in_an_innings  \
# 69         36.6                           5                           2
# 58         33.8                           5                           2
# 13         36.3                          12                           1
# 17         35.8                           7                           1
# 37         32.7                           6                           1
# 52         33.8                           4                           2
# 36         40.6                           3                           1
# 16         39.8                           9                           3
# 21         35.6                          11                           2
# 40         41.4                           3                           1
#
#    played_for_ICC played_for_Austrailia played_for_Bangladesh played_for_Asia  \
# 69             No                    No                    No             Yes
# 58             No                    No                    No              No
# 13            Yes                   Yes                    No              No
# 17             No                    No                    No             Yes
# 37             No                    No                    No              No
# 52             No                    No                    No              No
# 36            Yes                    No                    No              No
# 16             No                    No                   Yes              No
# 21             No                    No                    No              No
# 40             No                    No                    No              No
#
#    played_for_Africa
# 69                No
# 58                No
# 13                No
# 17                No
# 37                No
# 52                No
# 36                No
# 16                No
# 21                No
# 40                No

# %% [markdown]
# Replace is used to replace the specific substring with the new defined ones.

# %% [markdown]
# ### Checking the unique values for country column

# %%
df['Country'].value_counts()
# Out:
# INDIA    13
# PAK      12
# AUS      10
# SL        9
# NZ        8
# SA        8
# WI        6
# ENG       6
# BAN       3
# AFG       1
# ZIM       1
# Name: Country, dtype: int64

# %%
# count no. of unique 
# values in Country column
n = df['Country'].nunique()
  
print("No.of.unique values in Country column :", n)
# Out:
# No.of.unique values in Country column : 11

# %% [markdown]
# ##### Here, we can see there are 11 different countries in the Country column.

# %%
display(df.sample(20))
# Out:
#          Player_Name Country  Years_played  Matches_Played  Innings_Played  \
# 2      Waqar Younis      PAK            14             262             258
# 19        AA Donald       SA            12             164             162
# 39         DW Steyn       SA            14             125             124
# 40       BKV Prasad    INDIA             7             161             160
# 45       TG Southee       NZ            12             143             141
# 55       NW Bracken      AUS             8             116             116
# 33     Abdur Razzak      BAN            10             153             152
# 48     CRD Fernando       SL            11             147             141
# 70          GB Hogg      AUS            12             123             113
# 3        WPUJC Vaas       SL            14             322             320
# 9          A Kumble    INDIA            17             271             265
# 23  Harbhajan Singh    INDIA            17             236             227
# 62         CH Gayle       WI            20             301             199
# 34     CJ McDermott      AUS            11             138             138
# 59       A Flintoff      ENG            10             141             119
# 57         JDP Oram       NZ            11             160             154
# 71        CR Woakes      ENG            10             106             102
# 46         M Morkel       SA            11             117             114
# 4     Shahid Afridi      PAK            19             398             372
# 37         DJ Bravo       WI            10             164             150
#
#     Balls_Bowled  Runs_Yielded  Wickets_Taken  Bowling_Average  Economy_Rate  \
# 2          12698          9919            416            23.84          4.68
# 19          8561          5926            272            21.78          4.15
# 39          6256          5087            196            25.95          4.87
# 40          8129          6332            196            32.30          4.67
# 45          7195          6558            190            34.51          5.46
# 55          5759          4240            174            24.36          4.41
# 33          7965          6065            207            29.29          4.56
# 48          6507          5648            187            30.20          5.20
# 70          5564          4188            156            26.84          4.51
# 3          15775         11014            400            27.53          4.18
# 9          14496         10412            337            30.89          4.30
# 23         12479          8973            269            33.35          4.31
# 62          7424          5926            167            35.48          4.78
# 34          7461          5018            203            24.71          4.03
# 59          5624          4121            169            24.38          4.39
# 57          6911          5047            173            29.17          4.38
# 71          5016          4567            155            29.46          5.46
# 46          5760          4761            188            25.32          4.95
# 4          17670         13632            395            34.51          4.62
# 37          6511          5874            199            29.51          5.41
#
#     Strike_Rate  Four_Wickets_in_an_innings  Five_Wickets_in_an_innings  \
# 2          30.5                          14                          13
# 19         31.4                          11                           2
# 39         31.9                           4                           3
# 40         41.4                           3                           1
# 45         37.8                           4                           3
# 55         33.0                           5                           2
# 33         38.4                           5                           4
# 48         34.7                           3                           1
# 70         35.6                           3                           2
# 3          39.4                           9                           4
# 9          43.0                           8                           2
# 23         46.3                           2                           3
# 62         44.4                           3                           1
# 34         36.7                           4                           1
# 59         33.2                           6                           2
# 57         39.9                           3                           2
# 71         32.3                          10                           3
# 46         30.6                           7                           2
# 4          44.7                           4                           9
# 37         32.7                           6                           1
#
#    played_for_ICC played_for_Austrailia played_for_Bangladesh played_for_Asia  \
# 2              No                    No                    No              No
# 19             No                    No                    No              No
# 39             No                    No                    No              No
# 40             No                    No                    No              No
# 45             No                    No                    No              No
# 55             No                   Yes                    No              No
# 33             No                    No                   Yes              No
# 48             No                    No                    No             Yes
# 70             No                   Yes                    No              No
# 3              No                    No                    No             Yes
# 9              No                    No                    No             Yes
# 23             No                    No                    No             Yes
# 62            Yes                    No                    No              No
# 34             No                   Yes                    No              No
# 59            Yes                    No                    No              No
# 57             No                    No                    No              No
# 71             No                    No                    No              No
# 46             No                    No                    No              No
# 4             Yes                    No                    No             Yes
# 37             No                    No                    No              No
#
#    played_for_Africa
# 2                 No
# 19                No
# 39               Yes
# 40                No
# 45                No
# 55                No
# 33                No
# 48                No
# 70                No
# 3                 No
# 9                 No
# 23                No
# 62                No
# 34                No
# 59                No
# 57                No
# 71                No
# 46               Yes
# 4                 No
# 37                No

# %% [markdown]
# Here , as we have seperate columns to know whether the player played for ICC or Asia or Africa, there is no need to have them in the country column as well. In this way, we can get rid of redundant information from our dataset.
